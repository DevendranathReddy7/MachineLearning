# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataSet = pd.read_csv("50_startups.csv")
x = dataSet.iloc[:,:-1].values
y = dataSet.iloc[:,-1].values

# %%
#converting Non Numerical indepenent values to binary
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [3])],remainder = 'passthrough')
#3 is the index value of non numerical data
x = np.array(ct.fit_transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
np.set_printoptions(precision=2) # rounding results to 2 decimals
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)) 
# comparing predicted Y values with actual values
# Out:
# [[113314.99 105008.31]
#  [ 57977.52  69758.98]
#  [ 45651.07  42559.73]
#  [ 99214.62  97427.84]
#  [133745.54 146121.95]
#  [ 66570.61  81229.06]
#  [159942.68 156122.51]
#  [128367.2  134307.35]
#  [ 97024.52  99937.59]
#  [ 72470.48  90708.19]]
